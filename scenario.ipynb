# %%
import pandas as pd
import math
import numpy as np

# %%
# Generate the data
def generate_data_questionnaire(parameter,option,df_group) :
    parameter
    option
    df_group

# %%
# Group of 2, 5, 10
